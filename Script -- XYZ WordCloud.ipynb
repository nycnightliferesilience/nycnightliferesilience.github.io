# %%
import numpy as np
from PIL import Image
from os import path
import matplotlib.pyplot as plt
import os
import random
import csv
import pandas as pd

from wordcloud import WordCloud

# %%
text = pd.read_csv('Bed-Stuy.csv_output.csv')

# %%
x = (os.path.splitext(os.path.basename('Bed-Stuy.csv_output.csv'))[0])
print(x)
# Out:
# Bed-Stuy.csv_output

# %%
y = (x.split('.')[0])
print(y)
# Out:
# Bed-Stuy

# %%
z = (os.path.splitext(os.path.basename('Bed-Stuy.png'))[0])
print(z)
# Out:
# Bed-Stuy

# %%
if y == z:
    print('strings equal')
else:
    print('strings not equal')
# Out:
# strings equal

# %%
data = dict(zip(text['word'].tolist(), text['count'].tolist()))

# %%
from wordcloud import WordCloud

wc = WordCloud(width=800, height=400).generate_from_frequencies(data)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
BedStuy = np.array(Image.open(y + ".png"))

# %%
# https://www.datacamp.com/community/tutorials/wordcloud-python
BedStuy = BedStuy*255

# %%
BedStuy
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
#wc = WordCloud(background_color='white', width=400, height=200, mask=BedStuy).generate_from_frequencies(data)

plt.figure(figsize=(15, 15))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.figure()
#plt.imshow(Chelsea, cmap=plt.cm.gray, interpolation='bilinear')
# plt.axis("off")
#plt.show()

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=BedStuy, contour_width=3, contour_color='firebrick').generate_from_frequencies(data)

# %%
#wc.to_file('N.png')
